# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('xanias_time_series_5000.csv',index_col=0,header=0)

# %%
df
# Out:
#         tau=17    tau=20    tau=22
# Nums
# 0     0.100000  0.100000  0.100000
# 1     0.109516  0.109516  0.109516
# 2     0.118127  0.118127  0.118127
# 3     0.125918  0.125918  0.125918
# 4     0.132968  0.132968  0.132968
# ...        ...       ...       ...
# 4995  0.830025  1.132218  0.809362
# 4996  0.781718  1.127305  0.791025
# 4997  0.734923  1.117440  0.777462
# 4998  0.689515  1.105655  0.771708
# 4999  0.645633  1.094549  0.776942
#
# [5000 rows x 3 columns]

# %%
plt.plot(df['tau=17'])
plt.rcParams["figure.figsize"] = (15,5)

# %%
plt.plot(df['tau=20'])
plt.rcParams["figure.figsize"] = (15,5)

# %%
plt.plot(df['tau=22'])
plt.rcParams["figure.figsize"] = (15,5)

# %%
df2=pd.read_csv('xanias_time_series_10000.csv',index_col=0,header=0)

# %%
df2
# Out:
#         tau=17    tau=20    tau=22
# Nums
# 0     0.100000  0.100000  0.100000
# 1     0.109516  0.109516  0.109516
# 2     0.118127  0.118127  0.118127
# 3     0.125918  0.125918  0.125918
# 4     0.132968  0.132968  0.132968
# ...        ...       ...       ...
# 9995  1.230289  0.893476  0.767419
# 9996  1.208787  0.860215  0.781949
# 9997  1.174978  0.832706  0.810304
# 9998  1.132963  0.810708  0.850938
# 9999  1.086596  0.793153  0.899630
#
# [10000 rows x 3 columns]

# %%
plt.plot(df2['tau=17'])
plt.rcParams["figure.figsize"] = (15,5)

# %%
plt.plot(df2['tau=20'])
plt.rcParams["figure.figsize"] = (15,5)

# %%
plt.plot(df2['tau=22'])
plt.rcParams["figure.figsize"] = (15,5)

# %%
plt.plot(df2['tau=22'][:800])
plt.rcParams["figure.figsize"] = (15,5)
plt.legend(['Time series for t=800'])
# plt.savefig('xanias_time_series_plotting.jpg', bbox_inches='tight')

# %% [markdown]
# #

# %%
tau6 = pd.read_csv('x0=0.1_tau=6_b0=0.2_g=0.1_n=10.csv',index_col=0,header=0)
# ΓΙΑ ΝΑ ΔΕΙΣ ΤΑ ΑΛΛΑ ΔΙΑΓΡΑΜΜΑΤΑ ΒΑΛΕ ΑΠΟ ΠΑΝΩ ',INDEX_COL=0'
# tau6_diff=np.log(tau6/tau6.shift(1)).dropna()
# plt.plot(tau6_diff)
# tau6_diff

# %%
tau10 = pd.read_csv('x0=0.1_tau=10_b0=0.2_g=0.1_n=10.csv',index_col=0,header=0)
# tau10_diff=np.log(tau10/tau10.shift(1)).dropna()
# plt.plot(tau10_diff)

# %%
tau14 = pd.read_csv('x0=0.1_tau=14_b0=0.2_g=0.1_n=10.csv',index_col=0,header=0)
# tau14_diff=np.log(tau14/tau14.shift(1)).dropna()
# plt.plot(tau14_diff)

# %%
tau17 = pd.read_csv('x0=0.1_tau=17_b0=0.2_g=0.1_n=10_1658161015.csv',index_col=0,header=0)
# tau17_diff=np.log(tau17/tau17.shift(1)).dropna()
# plt.plot(tau17_diff)

# %%
tau20 = pd.read_csv('x0=0.1_tau=20_b0=0.2_g=0.1_n=10_1658161015.csv',index_col=0,header=0)
# tau20_diff=np.log(tau20/tau20.shift(1)).dropna()
# plt.plot(tau20_diff)

# %%
tau22 = pd.read_csv('x0=0.1_tau=22_b0=0.2_g=0.1_n=10_1658161015.csv',index_col=0,header=0)
# tau22_diff=np.log(tau22/tau22.shift(1)).dropna()
# plt.plot(tau22_diff)

# %%
plt.plot(tau6)
plt.rcParams["figure.figsize"] = (10,5)

# %%
plt.plot(tau10)
plt.rcParams["figure.figsize"] = (10,5)

# %%
plt.plot(tau14)
plt.rcParams["figure.figsize"] = (10,5)

# %%
plt.plot(tau17)
plt.rcParams["figure.figsize"] = (10,5)

# %%
plt.plot(tau20)
plt.rcParams["figure.figsize"] = (10,5)

# %%
plt.plot(tau22)
plt.rcParams["figure.figsize"] = (10,5)

# %%
xt = pd.read_csv('x0=0.5_tau=22_b0=0.2_g=0.1_n=10.csv',index_col=0,header=0)
d = xt.iloc[0:800,0]
d.plot()
d.head(1).plot(style='rD',markersize=10)
plt.legend(['x0=0.5 tau=22 b0=0.2 g=0.1 n=10','starting value'])

# %%
xt1 = pd.read_csv('x0=0.8_tau=22_b0=0.2_g=0.1_n=10.csv',index_col=0,header=0)
x = xt1.iloc[0:800,0]
x.plot()
x.head(1).plot(style='rD',markersize=10)
plt.legend(['x0=0.8 tau=22 b0=0.2 g=0.1 n=10','starting value'])

# %%
xt2 = pd.read_csv('x0=1.2_tau=22_b0=0.2_g=0.1_n=10.csv',index_col=0,header=0)
y = xt2.iloc[0:800,0]
y.plot()
y.head(1).plot(style='rD',markersize=10)
plt.legend(['x0=1.2 tau=22 b0=0.2 g=0.1 n=10','starting value'])
